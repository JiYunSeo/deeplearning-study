# %%
import os
import cv2 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
rootPath = './train_posture'

# %%
imageGenerator = ImageDataGenerator(rescale=1./255,
                                    rotation_range=5,
                                    width_shift_range=0.03,
                                    height_shift_range=0.03,
                                    #horizontal_flip=False,
                                    validation_split=.2)

# %%
trainGen = imageGenerator.flow_from_directory(os.path.join(rootPath,'training_set'),
                                              target_size=(200,200),
                                              color_mode="grayscale",
                                              subset='training')

validationGen = imageGenerator.flow_from_directory(os.path.join(rootPath,'training_set'),
                                                    target_size=(200,200),color_mode="grayscale",
                                                    subset='validation')
# Out:
# Found 2323 images belonging to 5 classes.
# Found 577 images belonging to 5 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

model = Sequential()

# %%
model.add(layers.InputLayer(input_shape=(200,200,1)))
model.add(layers.Conv2D(16,(3,3),(1,1),'same',activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(rate=0.3))

model.add(layers.Conv2D(32, (3, 3), (1, 1), 'same', activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(rate=0.3))

model.add(layers.Conv2D(64, (3, 3), (1, 1), 'same', activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(rate=0.3))

model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dropout(rate=0.3))
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dropout(rate=0.3))
model.add(layers.Dense(5, activation='softmax'))

model.summary()
# Out:
# WARNING:tensorflow:From D:\anaconda\envs\gpu\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 200, 200, 16)      160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 100, 100, 16)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 100, 100, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 100, 100, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 50, 50, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50, 50, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 50, 50, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 25, 25, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 25, 25, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 40000)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               20480512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 2565
# =================================================================
# Total params: 20,769,029
# Trainable params: 20,769,029
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import optimizers

opt = optimizers.Adam(lr=0.0001)

model.compile(
    optimizer=opt,
    loss='categorical_crossentropy', 
    metrics=['acc'],
)

# %%
epochs = 32
es = EarlyStopping(monitor='val_loss', mode='min', patience=5)

history = model.fit_generator(
    trainGen, 
    epochs=epochs,
    steps_per_epoch=trainGen.samples / epochs, 
    validation_data=validationGen,
    validation_steps=trainGen.samples / epochs,
    callbacks=[es]
)
# Out:
# Epoch 1/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.5130 - acc: 0.8097Epoch 1/32
# 73/72 [==============================] - 9s 129ms/step - loss: 0.2838 - acc: 0.9536
# 73/72 [==============================] - 20s 269ms/step - loss: 0.5075 - acc: 0.8119 - val_loss: 0.2853 - val_acc: 0.9536
# Epoch 2/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0891 - acc: 0.9734Epoch 1/32
# 73/72 [==============================] - 9s 125ms/step - loss: 0.1282 - acc: 0.9938
# 73/72 [==============================] - 17s 235ms/step - loss: 0.0882 - acc: 0.9737 - val_loss: 0.1289 - val_acc: 0.9938
# Epoch 3/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0696 - acc: 0.9773Epoch 1/32
# 73/72 [==============================] - 9s 129ms/step - loss: 0.1773 - acc: 0.9447
# 73/72 [==============================] - 17s 239ms/step - loss: 0.0711 - acc: 0.9768 - val_loss: 0.1783 - val_acc: 0.9447
# Epoch 4/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0604 - acc: 0.9790Epoch 1/32
# 73/72 [==============================] - 10s 133ms/step - loss: 0.1079 - acc: 0.9804
# 73/72 [==============================] - 18s 245ms/step - loss: 0.0602 - acc: 0.9793 - val_loss: 0.1084 - val_acc: 0.9804
# Epoch 5/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0428 - acc: 0.9847Epoch 1/32
# 73/72 [==============================] - 9s 125ms/step - loss: 0.0831 - acc: 0.9924
# 73/72 [==============================] - 17s 239ms/step - loss: 0.0423 - acc: 0.9849 - val_loss: 0.0835 - val_acc: 0.9924
# Epoch 6/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0367 - acc: 0.9882Epoch 1/32
# 73/72 [==============================] - 9s 124ms/step - loss: 0.0791 - acc: 0.9951
# 73/72 [==============================] - 17s 236ms/step - loss: 0.0371 - acc: 0.9879 - val_loss: 0.0795 - val_acc: 0.9951
# Epoch 7/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0301 - acc: 0.9900Epoch 1/32
# 73/72 [==============================] - 9s 124ms/step - loss: 0.0532 - acc: 0.9964
# 73/72 [==============================] - 17s 233ms/step - loss: 0.0297 - acc: 0.9901 - val_loss: 0.0535 - val_acc: 0.9964
# Epoch 8/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0274 - acc: 0.9917Epoch 1/32
# 73/72 [==============================] - 9s 125ms/step - loss: 0.0899 - acc: 0.9947
# 73/72 [==============================] - 17s 235ms/step - loss: 0.0298 - acc: 0.9910 - val_loss: 0.0904 - val_acc: 0.9947
# Epoch 9/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0364 - acc: 0.9887Epoch 1/32
# 73/72 [==============================] - 9s 125ms/step - loss: 0.0886 - acc: 0.9942
# 73/72 [==============================] - 17s 234ms/step - loss: 0.0360 - acc: 0.9888 - val_loss: 0.0891 - val_acc: 0.9942
# Epoch 10/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0187 - acc: 0.9935Epoch 1/32
# 73/72 [==============================] - 9s 124ms/step - loss: 0.0609 - acc: 0.9982
# 73/72 [==============================] - 17s 233ms/step - loss: 0.0185 - acc: 0.9935 - val_loss: 0.0612 - val_acc: 0.9982
# Epoch 11/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0114 - acc: 0.9965Epoch 1/32
# 73/72 [==============================] - 9s 125ms/step - loss: 0.0440 - acc: 0.9996
# 73/72 [==============================] - 17s 235ms/step - loss: 0.0112 - acc: 0.9966 - val_loss: 0.0443 - val_acc: 0.9996
# Epoch 12/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0155 - acc: 0.9969Epoch 1/32
# 73/72 [==============================] - 9s 125ms/step - loss: 0.0711 - acc: 0.9924
# 73/72 [==============================] - 17s 236ms/step - loss: 0.0164 - acc: 0.9966 - val_loss: 0.0715 - val_acc: 0.9924
# Epoch 13/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0095 - acc: 0.9974Epoch 1/32
# 73/72 [==============================] - 9s 124ms/step - loss: 0.0289 - acc: 0.9960
# 73/72 [==============================] - 17s 234ms/step - loss: 0.0094 - acc: 0.9974 - val_loss: 0.0291 - val_acc: 0.9960
# Epoch 14/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0100 - acc: 0.9978Epoch 1/32
# 73/72 [==============================] - 9s 124ms/step - loss: 0.0411 - acc: 0.9942
# 73/72 [==============================] - 17s 233ms/step - loss: 0.0099 - acc: 0.9978 - val_loss: 0.0414 - val_acc: 0.9942
# Epoch 15/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0120 - acc: 0.9965Epoch 1/32
# 73/72 [==============================] - 9s 126ms/step - loss: 0.0762 - acc: 0.9773
# 73/72 [==============================] - 17s 234ms/step - loss: 0.0119 - acc: 0.9966 - val_loss: 0.0767 - val_acc: 0.9773
# Epoch 16/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0091 - acc: 0.9978Epoch 1/32
# 73/72 [==============================] - 9s 125ms/step - loss: 0.0276 - acc: 1.0000
# 73/72 [==============================] - 17s 235ms/step - loss: 0.0090 - acc: 0.9978 - val_loss: 0.0278 - val_acc: 1.0000
# Epoch 17/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0120 - acc: 0.9969Epoch 1/32
# 73/72 [==============================] - 9s 124ms/step - loss: 0.0255 - acc: 0.9987
# 73/72 [==============================] - 17s 234ms/step - loss: 0.0119 - acc: 0.9970 - val_loss: 0.0256 - val_acc: 0.9987
# Epoch 18/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0066 - acc: 0.9991Epoch 1/32
# 73/72 [==============================] - 9s 128ms/step - loss: 0.0421 - acc: 0.9933
# 73/72 [==============================] - 17s 237ms/step - loss: 0.0066 - acc: 0.9991 - val_loss: 0.0423 - val_acc: 0.9933
# Epoch 19/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0046 - acc: 0.9987Epoch 1/32
# 73/72 [==============================] - 10s 130ms/step - loss: 0.0353 - acc: 0.9969
# 73/72 [==============================] - 18s 242ms/step - loss: 0.0045 - acc: 0.9987 - val_loss: 0.0355 - val_acc: 0.9969
# Epoch 20/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0020 - acc: 0.9996Epoch 1/32
# 73/72 [==============================] - 10s 131ms/step - loss: 0.0256 - acc: 0.9955
# 73/72 [==============================] - 18s 243ms/step - loss: 0.0020 - acc: 0.9996 - val_loss: 0.0258 - val_acc: 0.9955
# Epoch 21/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0068 - acc: 0.9969Epoch 1/32
# 73/72 [==============================] - 9s 125ms/step - loss: 0.0236 - acc: 0.9969
# 73/72 [==============================] - 17s 238ms/step - loss: 0.0069 - acc: 0.9970 - val_loss: 0.0237 - val_acc: 0.9969
# Epoch 22/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0078 - acc: 0.9974Epoch 1/32
# 73/72 [==============================] - 9s 126ms/step - loss: 0.0347 - acc: 0.9991
# 73/72 [==============================] - 17s 236ms/step - loss: 0.0077 - acc: 0.9974 - val_loss: 0.0349 - val_acc: 0.9991
# Epoch 23/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0050 - acc: 0.9987Epoch 1/32
# 73/72 [==============================] - 9s 128ms/step - loss: 0.0196 - acc: 0.9996
# 73/72 [==============================] - 17s 239ms/step - loss: 0.0049 - acc: 0.9987 - val_loss: 0.0197 - val_acc: 0.9996
# Epoch 24/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0041 - acc: 0.9987Epoch 1/32
# 73/72 [==============================] - 9s 129ms/step - loss: 0.0195 - acc: 0.9987
# 73/72 [==============================] - 18s 241ms/step - loss: 0.0040 - acc: 0.9987 - val_loss: 0.0196 - val_acc: 0.9987
# Epoch 25/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0068 - acc: 0.9974Epoch 1/32
# 73/72 [==============================] - 9s 126ms/step - loss: 0.0354 - acc: 1.0000
# 73/72 [==============================] - 18s 240ms/step - loss: 0.0067 - acc: 0.9974 - val_loss: 0.0356 - val_acc: 1.0000
# Epoch 26/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0014 - acc: 1.0000Epoch 1/32
# 73/72 [==============================] - 9s 126ms/step - loss: 0.0261 - acc: 0.9964
# 73/72 [==============================] - 17s 236ms/step - loss: 0.0014 - acc: 1.0000 - val_loss: 0.0263 - val_acc: 0.9964
# Epoch 27/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0034 - acc: 0.9983Epoch 1/32
# 73/72 [==============================] - 9s 125ms/step - loss: 0.0251 - acc: 0.9996
# 73/72 [==============================] - 17s 235ms/step - loss: 0.0034 - acc: 0.9983 - val_loss: 0.0253 - val_acc: 0.9996
# Epoch 28/32
# 72/72 [============================>.] - ETA: 0s - loss: 8.0075e-04 - acc: 1.0000Epoch 1/32
# 73/72 [==============================] - 9s 127ms/step - loss: 0.0168 - acc: 0.9987
# 73/72 [==============================] - 17s 238ms/step - loss: 7.9250e-04 - acc: 1.0000 - val_loss: 0.0169 - val_acc: 0.9987
# Epoch 29/32
# 72/72 [============================>.] - ETA: 0s - loss: 5.8582e-04 - acc: 1.0000Epoch 1/32
# 73/72 [==============================] - 9s 124ms/step - loss: 0.0123 - acc: 1.0000
# 73/72 [==============================] - 17s 236ms/step - loss: 5.8014e-04 - acc: 1.0000 - val_loss: 0.0124 - val_acc: 1.0000
# Epoch 30/32
# 72/72 [============================>.] - ETA: 0s - loss: 7.9156e-04 - acc: 0.9996Epoch 1/32
# 73/72 [==============================] - 9s 125ms/step - loss: 0.0179 - acc: 0.9973
# 73/72 [==============================] - 17s 234ms/step - loss: 7.8125e-04 - acc: 0.9996 - val_loss: 0.0180 - val_acc: 0.9973
# Epoch 31/32
# 72/72 [============================>.] - ETA: 0s - loss: 3.9944e-04 - acc: 1.0000Epoch 1/32
# 73/72 [==============================] - 9s 125ms/step - loss: 0.0097 - acc: 0.9991
# 73/72 [==============================] - 17s 234ms/step - loss: 3.9410e-04 - acc: 1.0000 - val_loss: 0.0098 - val_acc: 0.9991
# Epoch 32/32
# 72/72 [============================>.] - ETA: 0s - loss: 0.0043 - acc: 0.9991Epoch 1/32
# 73/72 [==============================] - 9s 125ms/step - loss: 0.0365 - acc: 0.9964
# 73/72 [==============================] - 17s 235ms/step - loss: 0.0042 - acc: 0.9991 - val_loss: 0.0367 - val_acc: 0.9964

# %%
import matplotlib.pyplot as plt
from pylab import figure, axes, pie, title, savefig

def show_graph(history_dict):
    accuracy = history_dict['acc']
    val_accuracy = history_dict['val_acc']
    loss = history_dict['loss']
    val_loss = history_dict['val_loss']

    epochs = range(1, len(loss) + 1)
    
    plt.figure(figsize=(16, 2))
    
    plt.subplot(121)
    plt.subplots_adjust(top=2)
    plt.plot(epochs, accuracy, label='Training accuracy')
    plt.plot(epochs, val_accuracy, label='Validation accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')

    plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1),
              fancybox=True, shadow=True, ncol=5)
#     plt.legend(bbox_to_anchor=(1, -0.1))

    plt.subplot(122)
    plt.plot(epochs, loss, label='Training loss')
    plt.plot(epochs, val_loss, label='Validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1),
          fancybox=True, shadow=True, ncol=5)
#     plt.legend(bbox_to_anchor=(1, 0))
    fig = plt.gcf()
    plt.show()
    fig.savefig('./posture_result/reslut00.png' ,bbox_inches='tight')
show_graph(history.history)

# %%
testGenerator = ImageDataGenerator(
    rescale=1./255
)

testGen = imageGenerator.flow_from_directory(
    os.path.join(rootPath, 'test_set'),
    color_mode="grayscale",
    target_size=(200, 200)
)

#model.evaluate_generator(testGen)
# Out:
# Found 61 images belonging to 5 classes.

# %%
from tensorflow.keras.preprocessing.image import array_to_img
import numpy as np

cls_index = ['Back', 'Front', 'Left', 'Nomal', 'Right']

imgs = testGen.next()
arr = imgs[0][0]
img = array_to_img(arr).resize((200, 200))
plt.imshow(img)
result = model.predict_classes(arr.reshape(1, 200, 200, 1))
print('예측: {}'.format(cls_index[result[0]]))
print('정답: {}'.format(cls_index[np.argmax(imgs[1][0])]))
# Out:
# 예측: Back
# 정답: Back

# %%
from tensorflow.keras.preprocessing.image import array_to_img
import numpy as np
from tqdm.notebook import tqdm

cls_index = ['Back', 'Front', 'Left', 'Nomal', 'Right']

correct_count = 0
total_count = 0

for i in tqdm(range(len(testGen.labels))):
    imgs = testGen.next()
    arr = imgs[0][0]
    img = array_to_img(arr).resize((200, 200))
#     plt.imshow(img)
    result = model.predict_classes(arr.reshape(1, 200, 200, 1))
#     print('예측: {}'.format(cls_index[result[0]]))
#     print('정답: {}'.format(cls_index[np.argmax(imgs[1][0])])) 
    
    total_count += 1
    if cls_index[result[0]] == cls_index[np.argmax(imgs[1][0])]:
        correct_count += 1

print('전체횟수:{0}, 정답횟수:{1}, 정답률:{2}'.format(total_count, correct_count, correct_count/total_count))
plt.imshow(img)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# 전체횟수:61, 정답횟수:61, 정답률:1.0
